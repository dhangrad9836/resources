# %% [markdown]
# <a href="https://colab.research.google.com/github/dhangrad9836/resources/blob/master/sent_analy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vadersentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 5.9MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My twitter autho
consumer_key = 'gmtRIUDhNbE5YXuAorhBD5PNt'
consumer_secret = 't8iFnxIu9kLWc7rY6T5cVj2SnDX0MuvrqNjFZWvvbtrvlQ4kRz'
access_token = '837555295-pIoegL9r6DPKoJl7jVqXpHIQ9Uy1sWzRNXXq3zGo'
access_token_secret = 'bixYyj0LuRZAc00Eeky6GF8zB9xZhM07zk5oFirHZ77K7'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @TheStreet: “There will be a continuation o...
# 1  RT @MicrosoftIndia: Join @sangeetagupta29 in a...
# 2  மனித ஜினோமில் புதிய ஆய்வு – செயற்கை நுண்ணறிவு ...
# 3  RT @MFordFuture: Inside Finland’s plan to beco...
# 4  Future Timeline: The #future of #robots and ar...
# 5  RT @fortivus: 3 Top Artificial Intelligence St...
# 6  RT @MFordFuture: Inside Finland’s plan to beco...
# 7  RT @DD_Wen_: Our Final Invention: Artificial I...
# 8  Inside Finland’s plan to become an artificial ...
# 9  RT @alankurtzpro: @Kaidinn Cassie @iHateCogsci...
# 2019-02-17 06:26:53

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []


for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @TheStreet: “There will be a continuation o...
# 1   RT @MicrosoftIndia: Join @sangeetagupta29 in a...
# 2   மனித ஜினோமில் புதிய ஆய்வு – செயற்கை நுண்ணறிவு ...
# 3   RT @MFordFuture: Inside Finland’s plan to beco...
# 4   Future Timeline: The #future of #robots and ar...
# 5   RT @fortivus: 3 Top Artificial Intelligence St...
# 6   RT @MFordFuture: Inside Finland’s plan to beco...
# 7   RT @DD_Wen_: Our Final Invention: Artificial I...
# 8   Inside Finland’s plan to become an artificial ...
# 9   RT @alankurtzpro: @Kaidinn Cassie @iHateCogsci...
# 10  RT @ipfconline1: Artificial Intelligence an “A...
# 11  RT @SwissCognitive: Applying just a bit of str...
# 12  RT @MicrosoftIndia: Join @sangeetagupta29 in a...
# 13  In the era of Artificial intelligence, I just ...
# 14  If Monsanto can use AI to drastically reduce t...
# 15  RT @techreview: A literal AI arms race is unde...
# ...
